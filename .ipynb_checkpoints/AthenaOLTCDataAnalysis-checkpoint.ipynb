# %% [markdown]
# ## Athena Online Learning Platform Data Analysis
# This notebook contains sketches for analyzing data from Athena Online Learning Platform.
# It will include analysis of tutoring data such as time of requests, subjects, and content.
# The purpose will be to understand what questions students are asking, and see if insight can be gained on what areas of a curriculum can be improved, or what help can be offered to a student for particular subjects
#
# ### Data Collected:
# Data will be collected directly from AthenaOLTC.com's public API. The information exposed by the API will only be data that can be viewed publicly on the main website.
#
# URI: http://www.athenaoltc.com
#
# Tutoring data: /api/tutoring/
#
# Events data: /api/events/
#
# ### Methods of Analysis:
# Various methods will be used to analyze the data.
#
# Time series plots can be used to view the usage of Athena-- if there is fluctuation in engagement on Athena, what subjects are asked about and when (and how the questions align with course schedule), as well as if people continue to use Athena.
#
# Tutoring request word clouds can help show what students are having trouble with. 'Pandas' value counts of subjects can show what subjects students get help in most on Athena. Bonus: given a set of words assigned to various levels of proficiency for a subject, it may be possible to estimate a student's proficiency within that subject by passing their tutoring request through a function that uses the predetermined proficiency values for each word to output some numerical value for student's proficiency.

# %%
# Step one: Collect data
import json
import sys
import urllib2

uri = 'http://www.athenaoltc.com/api/'
endpoints = {
    'tutoring': 'tutoring',
    'events': 'events'
}

# Test if API endpoints are working
try:
    tutoring = urllib2.urlopen(uri + endpoints['tutoring']).read()
    events = urllib2.urlopen(uri + endpoints['events']).read()

    tutoringJSON = json.loads(tutoring)
    eventsJSON = json.loads(events)

    with open('tutoring.json', 'w') as f:
        json.dump(tutoringJSON, f)
    
    with open('events.json', 'w') as f:
        json.dump(eventsJSON, f)

    sizeofTutoring = sys.getsizeof(tutoring)
    sizeofEvents = sys.getsizeof(events)
    
    print('Byte size of tutoring data: '+str(sizeofTutoring)+" bytes.")
    print('Byte size of events data: '+str(sizeofEvents)+" bytes.")
    print('\nAPI data read and stored successfully...')
except:
    print('API access failed...')
# Out:
# Byte size of tutoring data: 140640 bytes.
# Byte size of events data: 4901 bytes.
#
# API data read and stored successfully...

# %%
# I'm running this once to get all the columns displayed for me.
# I'm going to use the printed columns to manually list the columns I want and in what order.
# This is so that I can control the way the data is loaded into pandas DataFrame
# tutoringColumns = tutoringJSON[0].keys()
# eventsColumns = eventsJSON[0].keys()

# print(tutoringColumns)
# print(eventsColumns)

tutoringColumns = [
    'student_first_name',
    'student_last_name',
    'subject',
    'subject_number',
    'method',
    'appointment_time',
    'is_fulfilled',
    'instructor',
    'date_time_of_request',
    'semester',
    'responding_tutor',
    'response_time',
    'new_responses',
    'problem',
    'attachments'
]
eventsColumns = [
    'subject',
    'subject_number',
    'coordinator',
    'attendees',
    'title',
    'description',
    'date',
    'closed',
    'online',
    'location',
    'private'
]

# %%
# Column order has been determined, reshape json data into what's defined by the columns. This is necessary
# in order to format data being put into Pandas DataFrame
tutoringData = []
for entry in tutoringJSON:
    tutoringData.append([entry[field] for field in tutoringColumns])

eventsData = []
for entry in eventsJSON:
    eventsData.append([entry[field] for field in eventsColumns])

# %%
import pandas as pd
import numpy as np

tutoringFrame = pd.DataFrame(tutoringData, columns=tutoringColumns)
tutoringFrame
# Out:
#    student_first_name student_last_name                  subject  \
# 0            Obianuju           Ukwuoma  {u'shorthand': u'Calc'}
# 1              Nadeje          Sullivan  {u'shorthand': u'Math'}
# 2           Vinh Xuan            Nguyen  {u'shorthand': u'ENGL'}
# 3              Pamela       Shinholster  {u'shorthand': u'Micr'}
# 4              Eui Je               Won  {u'shorthand': u'Comp'}
# 5            Obianuju           Ukwuoma  {u'shorthand': u'Calc'}
# 6             Shanice          Benjamin  {u'shorthand': u'CHEM'}
# 7              Zalika             Moore  {u'shorthand': u'alge'}
# 8              Nadeje          Sullivan  {u'shorthand': u'Math'}
# 9             Jasmine            Mbonzo  {u'shorthand': u'Phys'}
# 10             Nadeje          Sullivan  {u'shorthand': u'Math'}
# 11             simone             jones  {u'shorthand': u'math'}
# 12              Emily        Richardson  {u'shorthand': u'Engl'}
# 13             Esther             Oliva  {u'shorthand': u'Math'}
# 14            Lismary          Santiago  {u'shorthand': u'Engl'}
# 15        NSENGIYUMVA             SHUBI  {u'shorthand': u'ENGL'}
# 16            Lismary          Santiago  {u'shorthand': u'Engl'}
# 17              Sarah              Bova  {u'shorthand': u'engl'}
# 18           Philicia          Halstion  {u'shorthand': u'chem'}
# 19             lauren         mulvihill  {u'shorthand': u'engl'}
# 20             Mylena           Moretti  {u'shorthand': u'ENGL'}
# 21               Will            Simson  {u'shorthand': u'HIST'}
# 22             Ashlyn            Lummus  {u'shorthand': u'Engl'}
# 23            Jessica           Delgado  {u'shorthand': u'Engl'}
# 24        shantescika              wade  {u'shorthand': u'Engl'}
# 25        Christopher             Haney  {u'shorthand': u'ENGL'}
# 26              Kathy             Riley  {u'shorthand': u'engl'}
# 27            Chandra          Brubaker  {u'shorthand': u'Engl'}
# 28               Ajia               Kim  {u'shorthand': u'biol'}
# 29            Chandra          Brubaker  {u'shorthand': u'Engl'}
# ..                ...               ...                      ...
# 65               Kyle              Moon  {u'shorthand': u'engl'}
# 66          Christina         Crossland  {u'shorthand': u'Engl'}
# 67              Sandi   Peterson-Cooper  {u'shorthand': u'Nonp'}
# 68             Payton            Aussin  {u'shorthand': u'engl'}
# 69            Brandon            Spence  {u'shorthand': u'Coll'}
# 70             Summer              King  {u'shorthand': u'chem'}
# 71           Tequilia           Roberts  {u'shorthand': u'Engl'}
# 72          Christina         Crossland  {u'shorthand': u'Engl'}
# 73               Paul            Haynes  {u'shorthand': u'engl'}
# 74             Antone             Faria  {u'shorthand': u'Engl'}
# 75            Raymond              Diaz  {u'shorthand': u'math'}
# 76              Ciara            Butler  {u'shorthand': u'engl'}
# 77        Christopher             Haney  {u'shorthand': u'ENGL'}
# 78            Jessica           Delgado  {u'shorthand': u'Engl'}
# 79             Teresa         Rodriguez  {u'shorthand': u'Psyc'}
# 80            hakimah            archie  {u'shorthand': u'engl'}
# 81            hakimah            archie  {u'shorthand': u'engl'}
# 82            hakimah            archie  {u'shorthand': u'engl'}
# 83            hakimah            archie  {u'shorthand': u'engl'}
# 84           Emmanuel         Asekhamhe  {u'shorthand': u'engl'}
# 85           Emmanuel         Asekhamhe  {u'shorthand': u'engl'}
# 86           Emmanuel         Asekhamhe  {u'shorthand': u'engl'}
# 87               Eric             Nunez  {u'shorthand': u'comp'}
# 88              Maria         Carachure  {u'shorthand': u'ENGL'}
# 89              Marva            Swayne  {u'shorthand': u'math'}
# 90              Aisha             Evans  {u'shorthand': u'Lite'}
# 91            Tiffany            Fuller  {u'shorthand': u'ENGL'}
# 92              Emily           Jenkins  {u'shorthand': u'Engl'}
# 93               Inez        Villanueva  {u'shorthand': u'Engl'}
# 94               Bria          McKinney  {u'shorthand': u'engl'}
#
#     subject_number method      appointment_time  is_fulfilled  \
# 0             2211   live  2017-06-28T18:00:00Z          True
# 1             1113  email  2017-09-01T18:00:00Z          True
# 2             1102  email  2017-08-29T23:00:00Z          True
# 3             2300   live  2017-08-29T21:00:00Z          True
# 4                1  email  2017-06-29T22:00:00Z          True
# 5               39   live  2017-06-29T16:00:00Z          True
# 6             1212  email  2017-07-25T01:00:00Z          True
# 7                0   live  2017-08-17T14:00:00Z          True
# 8             1113  email  2017-08-27T00:00:00Z          True
# 9             2212   live  2017-09-01T12:00:00Z          True
# 10            1113  email  2017-09-02T17:00:00Z          True
# 11            2008   live  2017-09-01T05:00:00Z          True
# 12            1101  email  2017-08-31T18:00:00Z          True
# 13            1070  email  2017-09-04T23:00:00Z          True
# 14            1101   live  2017-09-06T17:00:00Z          True
# 15               1  email  2017-09-06T17:00:00Z          True
# 16            1101   live  2017-09-06T14:00:00Z          True
# 17            1101  email  2017-09-08T03:00:00Z          True
# 18            1152   live  2017-09-06T16:00:00Z          True
# 19             999   live  2017-09-13T17:00:00Z          True
# 20               1  email  2017-09-09T23:00:00Z          True
# 21            1111   live  2017-09-13T19:00:00Z          True
# 22            1101   live  2017-09-13T23:00:00Z          True
# 23            1101  email  2017-09-14T11:00:00Z          True
# 24            1101   live  2017-09-11T17:00:00Z          True
# 25             570  email  2017-09-16T13:00:00Z          True
# 26            1102  email  2017-09-15T13:00:00Z          True
# 27            1101   live  2017-09-20T19:00:00Z          True
# 28            2110   live  2017-09-28T19:15:00Z          True
# 29            1101  email  2017-09-19T20:00:00Z          True
# ..             ...    ...                   ...           ...
# 65            1101  email  2017-10-08T20:00:00Z          True
# 66            1102  email  2017-10-11T16:00:00Z          True
# 67            8261   live  2017-10-10T15:00:00Z          True
# 68            1101  email  2017-10-10T16:00:00Z          True
# 69            1111   live  2017-10-10T13:00:00Z          True
# 70            1151   live  2017-10-10T23:00:00Z          True
# 71            1101  email  2017-10-09T21:00:00Z          True
# 72            1102   live  2017-10-11T17:00:00Z          True
# 17  {u'first_name': u'Maria', u'last_name': u'Batt...
# 18  {u'first_name': u'Theo', u'last_name': u'Tate'...
# 19  {u'first_name': u'Maria', u'last_name': u'Batt...
# 20  {u'first_name': u'Maria', u'last_name': u'Batt...
# 21  {u'first_name': u'Maria', u'last_name': u'Batt...
# 22  {u'first_name': u'Maria', u'last_name': u'Batt...
# 23  {u'first_name': u'Maria', u'last_name': u'Batt...
# 24  {u'first_name': u'Maria', u'last_name': u'Batt...
# 25  {u'first_name': u'Maria', u'last_name': u'Batt...
# 26  {u'first_name': u'Maria', u'last_name': u'Batt...
# 27  {u'first_name': u'Maria', u'last_name': u'Batt...
# 28  {u'first_name': u'Theo', u'last_name': u'Tate'...
# 29  {u'first_name': u'Maria', u'last_name': u'Batt...
# ..                                                ...
# 65  {u'first_name': u'Maria', u'last_name': u'Batt...
# 66  {u'first_name': u'Maria', u'last_name': u'Batt...
# 67  {u'first_name': u'Theo', u'last_name': u'Tate'...
# 68  {u'first_name': u'Maria', u'last_name': u'Batt...
# 69  {u'first_name': u'Theo', u'last_name': u'Tate'...
# 70  {u'first_name': u'Theo', u'last_name': u'Tate'...
# 71  {u'first_name': u'Maria', u'last_name': u'Batt...
# 72  {u'first_name': u'Maria', u'last_name': u'Batt...
# 73  {u'first_name': u'Maria', u'last_name': u'Batt...
# 74  {u'first_name': u'Maria', u'last_name': u'Batt...
# 75  {u'first_name': u'Vu', u'last_name': u'Le', u'...
# 76  {u'first_name': u'Maria', u'last_name': u'Batt...
# 77  {u'first_name': u'Maria', u'last_name': u'Batt...
# 78  {u'first_name': u'Maria', u'last_name': u'Batt...
# 79  {u'first_name': u'Maria', u'last_name': u'Batt...
# 80  {u'first_name': u'Maria', u'last_name': u'Batt...
# 81  {u'first_name': u'Maria', u'last_name': u'Batt...
# 82  {u'first_name': u'Maria', u'last_name': u'Batt...
# 83  {u'first_name': u'Maria', u'last_name': u'Batt...
# 84  {u'first_name': u'Maria', u'last_name': u'Batt...
# 85  {u'first_name': u'Maria', u'last_name': u'Batt...
# 86  {u'first_name': u'Maria', u'last_name': u'Batt...
# 87  {u'first_name': u'Jay', u'last_name': u'Dosunm...
# 88  {u'first_name': u'Maria', u'last_name': u'Batt...
# 89                                               None
# 90  {u'first_name': u'Maria', u'last_name': u'Batt...
# 91                                               None
# 92                                               None
# 93                                               None
# 94                                               None
#
#                   response_time  new_responses  \
# 0   2017-06-27T19:08:24.030437Z           True
# 1   2017-09-01T20:24:52.765061Z          False
# 2   2017-08-30T13:53:01.285540Z           True
# 3   2017-08-30T14:20:58.789943Z           True
# 4   2017-06-29T13:25:12.773181Z          False
# 5   2017-06-29T20:04:27.434737Z           True
# 6   2017-07-25T17:33:50.742514Z           True
# 7   2017-08-18T15:59:16.181500Z           True
# 8   2017-08-27T03:40:04.651643Z          False
# 9   2017-09-01T19:44:12.169506Z           True
# 10  2017-09-05T16:35:51.205669Z          False
# 16  Hello! I'm creating a mission statement essay ...
# 17  I have a restaurant review essay due as my fir...
# 18  I am having a hard time understanding the cis-...
# 19  I have a restaurant review for my English 1101...
# 20  Good afternoon.\r\nI'd like to ask help about ...
# 21                    HIST 1111 World History to 1500
# 22  I would usually never want to branch for a dif...
# 23  Hello, I have an essay due soon and I need hel...
# 24  Hello, I am a student of English class 1101, a...
# 25  I have my first Essay due soon. We had to writ...
# 26                          Please review this essay.
# 27  Review my Essay for English Comp. I also submi...
# 28  I am having trouble keeping up in my lecture c...
# 29  Please proof my draft essay not finished with ...
# ..                                                ...
# 65  I am writing my second essay, I've attached it...
# 66  I am writing an analytical essay and I just wo...
# 67  Hi,\r\n\r\nI need help in learning the various...
# 68  I am submitting my document which has all of t...
# 69  I got a test today, and i want you to explain ...
# 70  I need help with Nuclear Chemistry, compounds ...
# 71  I am required to have at least one essay tutor...
# 72  I am writing an anaylisis essay I just would l...
# 73  The Value of Diversity.  Both King and Wiesel ...
# 74  I'm looking for feedback on  how to make this ...
# 75  I request help in Math (generally) considering...
# 76  This essay is on the values of Dr. Martin Luth...
# 77  I know have some Grammar issues, I need help P...
# 78  Hello,  I was asked to write an essay and thes...
# 79  I need help with psychology and trying to unde...
# 80  My essay that I am writing about it the Martin...
# 81  My essay that I am writing about it the Martin...
# 82  My essay that I am writing about it the Martin...
# 83  My essay that I am writing about it the Martin...
# 84  My essay is attached below, and i will be grat...
# 85  My essay is attached below, and i will be grat...
# 86  My essay is attached below, and i will be grat...
# 87  "A certain bank offers 6.5% interest on saving...
# 88  During class, we have read Martin Luther King ...
# 89  I need help on math 1001 the formulas for annu...
# 90  I just want someone to look over my research e...
# 91  Good afternoon,\r\n\r\nCan you please review m...
# 92  I am writing a comparison/contrast essay. The ...
# 93  I need help editing my third essay for english...
# 94  I would like for someone to review my essay to...
#
#                                           attachments
# 0                                                None
# 1   https://athena-learning-platform.s3.amazonaws....
# 2   https://athena-learning-platform.s3.amazonaws....
# 3                                                None
# 4   https://athena-learning-platform.s3.amazonaws....
# 5                                                None
# 6   https://athena-learning-platform.s3.amazonaws....
# 7                                                None
# 8                                                None
# 9                                                None
# 10  https://athena-learning-platform.s3.amazonaws....
# 11                                               None
# 12  https://athena-learning-platform.s3.amazonaws....
# 13                                               None
# 14  https://athena-learning-platform.s3.amazonaws....
# 15  https://athena-learning-platform.s3.amazonaws....
# 16  https://athena-learning-platform.s3.amazonaws....
# 17  https://athena-learning-platform.s3.amazonaws....
# 18  https://athena-learning-platform.s3.amazonaws....
# 19                                               None
# 20  https://athena-learning-platform.s3.amazonaws....
# 21                                               None
# 22                                               None
# 23  https://athena-learning-platform.s3.amazonaws....
# 24  https://athena-learning-platform.s3.amazonaws....
# 25  https://athena-learning-platform.s3.amazonaws....
# 26  https://athena-learning-platform.s3.amazonaws....
# 27  https://athena-learning-platform.s3.amazonaws....
# 28                                               None
# 29  https://athena-learning-platform.s3.amazonaws....
# ..                                                ...
# 65  https://athena-learning-platform.s3.amazonaws....
# 66  https://athena-learning-platform.s3.amazonaws....
# 67                                               None
# 68  https://athena-learning-platform.s3.amazonaws....
# 69                                               None
# 70                                               None
# 71  https://athena-learning-platform.s3.amazonaws....
# 72  https://athena-learning-platform.s3.amazonaws....
# 73  https://athena-learning-platform.s3.amazonaws....
# 74  https://athena-learning-platform.s3.amazonaws....
# 75                                               None
# 76                                               None
# 77  https://athena-learning-platform.s3.amazonaws....
# 78  https://athena-learning-platform.s3.amazonaws....
# 79                                               None
# 80  https://athena-learning-platform.s3.amazonaws....
# 81  https://athena-learning-platform.s3.amazonaws....
# 82  https://athena-learning-platform.s3.amazonaws....
# 83  https://athena-learning-platform.s3.amazonaws....
# 84  https://athena-learning-platform.s3.amazonaws....
# 85  https://athena-learning-platform.s3.amazonaws....
# 86  https://athena-learning-platform.s3.amazonaws....
# 87                                               None
# 88  https://athena-learning-platform.s3.amazonaws....
# 89                                               None
# 90                                               None
# 91  https://athena-learning-platform.s3.amazonaws....
# 92  https://athena-learning-platform.s3.amazonaws....
# 93  https://athena-learning-platform.s3.amazonaws....
# 94  https://athena-learning-platform.s3.amazonaws....
#
# [95 rows x 15 columns]

# %%
# Okay data is all loaded. Time to analyze
print('Subjects:')
print(tutoringFrame['subject'].value_counts())
print('\nStudents: ')
print(tutoringFrame['student_first_name'].value_counts())
print('\nTutors: ')
print(tutoringFrame['responding_tutor'].value_counts())
# Out:
# Subjects:
# {u'shorthand': u'Engl'}    21
# {u'shorthand': u'engl'}    19
# {u'shorthand': u'ENGL'}    10
# {u'shorthand': u'chem'}     5
# {u'shorthand': u'math'}     4
# {u'shorthand': u'Math'}     4
# {u'shorthand': u'phil'}     4
# {u'shorthand': u'biol'}     3
# {u'shorthand': u'Calc'}     2
# {u'shorthand': u'Acco'}     2
# {u'shorthand': u'comp'}     1
# {u'shorthand': u'Comp'}     1
# {u'shorthand': u'Chem'}     1
# {u'shorthand': u'CS'}       1
# {u'shorthand': u'CHEM'}     1
# {u'shorthand': u'Lite'}     1
# {u'shorthand': u'ELEM'}     1
# {u'shorthand': u'firs'}     1
# {u'shorthand': u'PREC'}     1
# {u'shorthand': u'HIST'}     1
# {u'shorthand': u'geol'}     1
# {u'shorthand': u'Micr'}     1
# {u'shorthand': u'Phys'}     1
# {u'shorthand': u'anat'}     1
# {u'shorthand': u'Bask'}     1
# {u'shorthand': u'ha'}       1
# {u'shorthand': u'Nonp'}     1
# {u'shorthand': u'alge'}     1
# {u'shorthand': u'Coll'}     1
# {u'shorthand': u'acct'}     1
# {u'shorthand': u'Psyc'}     1
# Name: subject, dtype: int64
#
# Students:
# richard        4
# Carol          4
# hakimah        4
# Emily          3
# Nadeje         3
# Emmanuel       3
# Jessica        3
# Chandra        3
# Obianuju       2
# Christopher    2
# Lismary        2
# Christina      2
# James          2
# Ajia           2
# Payton         2
# Antone         2
# Sarah          2
# Amiracle       2
# Ciara          2
# lauren         1
# Jonathan       1
# Summer         1
# Jasmine        1
# Melody         1
# Raymond        1
# AVRIL          1
# Shanice        1
# Kathy          1
# Red            1
# Esther         1
#               ..
# Brandon        1
# Rhadejah       1
# Tequilia       1
# Philicia       1
# Sylvie         1
# Zalika         1
# Liz            1
# Inez           1
# Kyle           1
# Eui Je         1
# Tyrell         1
# Aisha          1
# Paul           1
# Ashlyn         1
# Marva          1
# Tiffany        1
# Will           1
# Maria          1
# Michael        1
# Andriana       1
# shantescika    1
# Sandi          1
# Vinh Xuan      1
# NSENGIYUMVA    1
# Teresa         1
# Daiane         1
# Katherine      1
# Bria           1
# jimicka        1
# Amira          1
# Name: student_first_name, Length: 65, dtype: int64
#
# Tutors:
# {u'first_name': u'Maria', u'last_name': u'Batty', u'is_active': True, u'user_type': u'admin', u'is_staff': False, u'date_joined': u'2017-06-14T20:06:28.929467Z'}       55
# {u'first_name': u'Theo', u'last_name': u'Tate', u'is_active': True, u'user_type': u'admin', u'is_staff': False, u'date_joined': u'2017-06-14T19:47:03.379479Z'}         24
# {u'first_name': u'Jay', u'last_name': u'Dosunmu', u'is_active': True, u'user_type': u'admin', u'is_staff': True, u'date_joined': u'2017-06-14T15:04:19.055323Z'}         7
# {u'first_name': u'Xin', u'last_name': u'Gao', u'is_active': True, u'user_type': u'tutor', u'is_staff': False, u'date_joined': u'2017-09-28T17:53:29.447199Z'}            1
# {u'first_name': u'Nancy', u'last_name': u'McDaniel', u'is_active': True, u'user_type': u'admin', u'is_staff': False, u'date_joined': u'2017-07-09T21:03:39.109869Z'}     1
# {u'first_name': u'Vu', u'last_name': u'Le', u'is_active': True, u'user_type': u'tutor', u'is_staff': False, u'date_joined': u'2017-10-13T12:12:19.544873Z'}              1
# Name: responding_tutor, dtype: int64

# %%
# Let's visualize activity on Athena: display the requests over time, also note unique student submissions.
import random
import matplotlib.pyplot as plt
# %matplotlib inline

x = [pd.to_datetime(d) for d in tutoringFrame.date_time_of_request]
# random.shuffle(x)
y = [f for f in tutoringFrame.student_first_name]

# tutoringFrame.plot(x='date_int', y='student_first_name', kind='scatter')

cmap = plt.get_cmap('viridis')
colors = cmap(np.linspace(0, 1, len(x)))
random.shuffle(colors)
# x.sort()

plt.scatter(x, y, s=50, c=colors)
plt.gray()

plt.show()

# %%
# Now, let's take a look at the word cloud for a subject
from wordcloud import WordCloud
BoW = [] # Create a bag of words

# Collect all the words in requests for math subjects
subject = ['math', 'Math', 'alge', 'Coll', 'acct']
for index, entry in tutoringFrame.iterrows():
    if (entry['subject']['shorthand'] in subject):
        BoW += entry['problem'].split()

BoW = ' '.join(BoW)
        
wc = WordCloud().generate(BoW)

# https://github.com/amueller/word_cloud
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")

# lower max_font_size
wordcloud = WordCloud(max_font_size=40).generate(BoW)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
